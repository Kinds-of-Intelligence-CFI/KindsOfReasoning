# %% [markdown]
# # Estimate cost of running a model on the KindsOfReasoning dataset

# %%
import pandas as pd

from set_up_datasets import DATASETS_DICT
from src.utils import compute_n_tokens, compute_cost

# enable reloading of modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
DATASETS_DICT
# Out:
# {'space_nli': set_up_datasets.SpaceNLI,
#  'anli': set_up_datasets.ANLI,
#  'copa': set_up_datasets.COPA,
#  'alpha_nli': set_up_datasets.AlphaNLI,
#  'wanli': set_up_datasets.WANLI,
#  'babi_task_16': set_up_datasets.bABItask16,
#  'ropes': set_up_datasets.ROPES,
#  'cosmos_qa': set_up_datasets.CosmosQA,
#  'formal_fallacies_syllogisms_negation': set_up_datasets.FormalFallaciesSyllogismsNegation,
#  'logical_args': set_up_datasets.LogicalArgs,
#  'crass_ai': set_up_datasets.CrassAI,
#  'geometric_shapes': set_up_datasets.GeometricShapes,
#  'emoji_movie': set_up_datasets.EmojiMovie,
#  'odd_one_out': set_up_datasets.OddOneOut,
#  'metaphor_boolean': set_up_datasets.MetaphorBoolean,
#  'fantasy_reasoning': set_up_datasets.FantasyReasoning,
#  'abstract_narrative_understanding': set_up_datasets.AbstractNarrativeUnderstanding,
#  'cause_and_effect': set_up_datasets.CauseAndEffect,
#  'goal_step_wikihow': set_up_datasets.GoalStepWikihow,
#  'arithmetic': set_up_datasets.Arithmetic}

# %%
len(DATASETS_DICT)
# Out:
# 20

# %% [markdown]
# # Extract the number of tokens for each dataset and the cost per model

# %% [markdown]
# ## Compute the number of tokens

# %%
registry_path = "1_evals_registry"

n_tokens_dict = {}
for dataset_id, dataset_class in DATASETS_DICT.items():
        
    # print(dataset_id)
    dataset = dataset_class()
    
    if hasattr(dataset, "subtasks") and dataset.subtasks is not None:
        subtasks = dataset.subtasks
        if not isinstance(subtasks, list):
            subtasks = [subtasks]
        
        filepath_list  = [dataset._get_samples_path(registry_path,subtask=subtask) for subtask in subtasks]
        # print(filepath_list)
    else:
        filepath_list = [dataset._get_samples_path(registry_path)]
        # print(filepath_list)
        
    # load the dataframe
    for filepath in filepath_list:
        print(filepath)
        original_df = pd.read_json(filepath, lines=True)
        original_df["n_tokens"] = original_df["input"].apply(
    lambda x: compute_n_tokens("System: " + x[0]["content"] + "\nUser: " + x[1]["content"] + "\nAnswer: ", tokenizer))
        print(filepath, len(original_df))
        n_tokens_dict[filepath] = original_df["n_tokens"].sum()
total_n_tokens = sum(n_tokens_dict.values())
# Out:
# 1_evals_registry/data/space_nli/samples.jsonl
# 1_evals_registry/data/space_nli/samples.jsonl 1600
# 1_evals_registry/data/anli/samples.jsonl
# 1_evals_registry/data/anli/samples.jsonl 3196
# 1_evals_registry/data/copa/samples.jsonl
# 1_evals_registry/data/copa/samples.jsonl 496
# 1_evals_registry/data/alpha_nli/samples.jsonl
# 1_evals_registry/data/alpha_nli/samples.jsonl 1528
# 1_evals_registry/data/wanli/samples.jsonl
# 1_evals_registry/data/wanli/samples.jsonl 4996
# 1_evals_registry/data/babi_task_16/samples.jsonl
# 1_evals_registry/data/babi_task_16/samples.jsonl 4996
# 1_evals_registry/data/ropes/samples.jsonl
# 1_evals_registry/data/arithmetic/4_digit_addition/samples.jsonl 996
# 1_evals_registry/data/arithmetic/5_digit_addition/samples.jsonl
# 1_evals_registry/data/arithmetic/5_digit_addition/samples.jsonl 996
# 1_evals_registry/data/arithmetic/1_digit_subtraction/samples.jsonl
# 1_evals_registry/data/arithmetic/1_digit_subtraction/samples.jsonl 96
# 1_evals_registry/data/arithmetic/2_digit_subtraction/samples.jsonl
# 1_evals_registry/data/arithmetic/2_digit_subtraction/samples.jsonl 996
# 1_evals_registry/data/arithmetic/3_digit_subtraction/samples.jsonl
# 1_evals_registry/data/arithmetic/3_digit_subtraction/samples.jsonl 996
# 1_evals_registry/data/arithmetic/4_digit_subtraction/samples.jsonl
# 1_evals_registry/data/arithmetic/4_digit_subtraction/samples.jsonl 996
# 1_evals_registry/data/arithmetic/5_digit_subtraction/samples.jsonl
# 1_evals_registry/data/arithmetic/5_digit_subtraction/samples.jsonl 996
# 1_evals_registry/data/arithmetic/1_digit_multiplication/samples.jsonl
# 1_evals_registry/data/arithmetic/1_digit_multiplication/samples.jsonl 96
# 1_evals_registry/data/arithmetic/2_digit_multiplication/samples.jsonl
# 1_evals_registry/data/arithmetic/2_digit_multiplication/samples.jsonl 996
# 1_evals_registry/data/arithmetic/3_digit_multiplication/samples.jsonl
# 1_evals_registry/data/arithmetic/3_digit_multiplication/samples.jsonl 996
# 1_evals_registry/data/arithmetic/4_digit_multiplication/samples.jsonl
# 1_evals_registry/data/arithmetic/4_digit_multiplication/samples.jsonl 996
# 1_evals_registry/data/arithmetic/5_digit_multiplication/samples.jsonl
# 1_evals_registry/data/arithmetic/5_digit_multiplication/samples.jsonl 996
# 1_evals_registry/data/arithmetic/1_digit_division/samples.jsonl
# 1_evals_registry/data/arithmetic/1_digit_division/samples.jsonl 19
# 1_evals_registry/data/arithmetic/2_digit_division/samples.jsonl
# 1_evals_registry/data/arithmetic/2_digit_division/samples.jsonl 196
# 1_evals_registry/data/arithmetic/3_digit_division/samples.jsonl
# 1_evals_registry/data/arithmetic/3_digit_division/samples.jsonl 496
# 1_evals_registry/data/arithmetic/4_digit_division/samples.jsonl
# 1_evals_registry/data/arithmetic/4_digit_division/samples.jsonl 996
# 1_evals_registry/data/arithmetic/5_digit_division/samples.jsonl
# 1_evals_registry/data/arithmetic/5_digit_division/samples.jsonl 996

# %% [markdown]
# ## Compute the cost per model

# %%
models_to_evaluate = ["gpt-4-0125-preview", "gpt-4-1106-preview", "gpt-4-0613", "gpt-4-0314",
"gpt-3.5-turbo-0125", "gpt-3.5-turbo-1106", "gpt-3.5-turbo-0613", "gpt-3.5-turbo-0301",]

# %%
total_cost = 0
for model_id in models_to_evaluate:
    print(f"Cost for {model_id}: {compute_cost(model_id, total_n_tokens):.2f}")
    total_cost += compute_cost(model_id, total_n_tokens)
print(f"Total cost: {total_cost:.2f}")
# Out:
# Cost for gpt-4-0125-preview: 76.28
# Cost for gpt-4-1106-preview: 76.28
# Cost for gpt-4-0613: 228.84
# Cost for gpt-4-0314: 228.84
# Cost for gpt-3.5-turbo-0125: 3.81
# Cost for gpt-3.5-turbo-1106: 7.63
# Cost for gpt-3.5-turbo-0613: 11.44
# Cost for gpt-3.5-turbo-0301: 11.44
# Total cost: 644.57

# %%
# convert n_tokens_dict to a dataframe
n_tokens_df = pd.DataFrame.from_dict(n_tokens_dict, orient="index", columns=["n_tokens"])

# %%
# add the cost
for model_id in models_to_evaluate:
    n_tokens_df[f"cost_{model_id}"] = n_tokens_df["n_tokens"].apply(lambda x: compute_cost(model_id, x))
n_tokens_df["total_cost"] = n_tokens_df[[f"cost_{model_id}" for model_id in models_to_evaluate]].sum(axis=1)

# %%
# add the number of samples in each row
for filepath in n_tokens_df.index:
    original_df = pd.read_json(filepath, lines=True)
    n_tokens_df.loc[filepath, "n_samples"] = len(original_df)

# %%
n_tokens_df = n_tokens_df.sort_values(by="total_cost", ascending=True)

# %%
n_tokens_df.head()
# Out:
#                                                     n_tokens  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...       703
# 1_evals_registry/data/cause_and_effect/one_sent...      1457
# 1_evals_registry/data/odd_one_out/samples.jsonl         2527
# 1_evals_registry/data/cause_and_effect/two_sent...      3015
# 1_evals_registry/data/cause_and_effect/one_sent...      3349
#
#                                                     cost_gpt-4-0125-preview  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...                  0.00703
# 1_evals_registry/data/cause_and_effect/one_sent...                  0.01457
# 1_evals_registry/data/odd_one_out/samples.jsonl                     0.02527
# 1_evals_registry/data/cause_and_effect/two_sent...                  0.03015
# 1_evals_registry/data/cause_and_effect/one_sent...                  0.03349
#
#                                                     cost_gpt-4-1106-preview  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...                  0.00703
# 1_evals_registry/data/cause_and_effect/one_sent...                  0.01457
# 1_evals_registry/data/odd_one_out/samples.jsonl                     0.02527
# 1_evals_registry/data/cause_and_effect/two_sent...                  0.03015
# 1_evals_registry/data/cause_and_effect/one_sent...                  0.03349
#
#                                                     cost_gpt-4-0613  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...          0.02109
# 1_evals_registry/data/cause_and_effect/one_sent...          0.04371
# 1_evals_registry/data/odd_one_out/samples.jsonl             0.07581
# 1_evals_registry/data/cause_and_effect/two_sent...          0.09045
# 1_evals_registry/data/cause_and_effect/one_sent...          0.10047
#
#                                                     cost_gpt-4-0314  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...          0.02109
# 1_evals_registry/data/cause_and_effect/one_sent...          0.04371
# 1_evals_registry/data/odd_one_out/samples.jsonl             0.07581
# 1_evals_registry/data/cause_and_effect/two_sent...          0.09045
# 1_evals_registry/data/cause_and_effect/one_sent...          0.10047
#
#                                                     cost_gpt-3.5-turbo-0125  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...                 0.000351
# 1_evals_registry/data/cause_and_effect/one_sent...                 0.000728
# 1_evals_registry/data/odd_one_out/samples.jsonl                    0.001263
# 1_evals_registry/data/cause_and_effect/two_sent...                 0.001507
# 1_evals_registry/data/cause_and_effect/one_sent...                 0.001674
#
#                                                     cost_gpt-3.5-turbo-1106  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...                 0.000703
# 1_evals_registry/data/arithmetic/5_digit_subtra...    3.254687
# 1_evals_registry/data/arithmetic/5_digit_divisi...    3.270066
# 1_evals_registry/data/copa/samples.jsonl              3.983414
# 1_evals_registry/data/metaphor_boolean/samples....    4.244350
# 1_evals_registry/data/geometric_shapes/samples....    4.281530
# 1_evals_registry/data/space_nli/samples.jsonl        11.783863
# 1_evals_registry/data/goal_step_wikihow/goal_in...   13.768092
# 1_evals_registry/data/abstract_narrative_unders...   14.135414
# 1_evals_registry/data/alpha_nli/samples.jsonl        15.454797
# 1_evals_registry/data/ropes/samples.jsonl            18.419986
# 1_evals_registry/data/abstract_narrative_unders...   18.553496
# 1_evals_registry/data/goal_step_wikihow/step_in...   19.892483
# 1_evals_registry/data/goal_step_wikihow/step_or...   28.728902
# 1_evals_registry/data/anli/samples.jsonl             41.197384
# 1_evals_registry/data/wanli/samples.jsonl            41.448856
# 1_evals_registry/data/babi_task_16/samples.jsonl     44.135364
# 1_evals_registry/data/cosmos_qa/samples.jsonl        52.928012
# 1_evals_registry/data/abstract_narrative_unders...   96.461482
# 1_evals_registry/data/formal_fallacies_syllogis...  163.674303

# %% [markdown]
# cumsum

# %%
n_tokens_df["cumsum_cost_instruct"] = n_tokens_df["total_cost"].cumsum()
n_tokens_df["cumsum_n_samples"] = n_tokens_df["n_samples"].cumsum()

# %%
n_tokens_df[["cumsum_cost_instruct", "total_cost", "cumsum_n_samples", "n_samples"]]
# Out:
#                                                     cumsum_cost_instruct  \
# 1_evals_registry/data/arithmetic/1_digit_divisi...              0.059403
# 1_evals_registry/data/cause_and_effect/one_sent...              0.182520
# 1_evals_registry/data/odd_one_out/samples.jsonl                 0.396052
# 1_evals_registry/data/cause_and_effect/two_sent...              0.650819
# 1_evals_registry/data/cause_and_effect/one_sent...              0.933810
# 1_evals_registry/data/arithmetic/1_digit_subtra...              1.225842
# 1_evals_registry/data/arithmetic/1_digit_additi...              1.517874
# 1_evals_registry/data/arithmetic/1_digit_multip...              1.809906
# 1_evals_registry/data/crass_ai/samples.jsonl                    2.144948
# 1_evals_registry/data/logical_args/samples.jsonl                2.637752
# 1_evals_registry/data/arithmetic/2_digit_divisi...              3.250546
# 1_evals_registry/data/emoji_movie/samples.jsonl                 3.958741
# 1_evals_registry/data/arithmetic/3_digit_divisi...              5.537032
# 1_evals_registry/data/fantasy_reasoning/samples...              7.168558
# 1_evals_registry/data/arithmetic/2_digit_multip...             10.198389
# 1_evals_registry/data/arithmetic/2_digit_subtra...             13.228221
# 1_evals_registry/data/arithmetic/2_digit_additi...             16.258053
# 1_evals_registry/data/arithmetic/3_digit_multip...             19.378723
# 1_evals_registry/data/arithmetic/3_digit_additi...             22.499984
# 1_evals_registry/data/arithmetic/3_digit_subtra...             25.624034
# 1_evals_registry/data/arithmetic/4_digit_multip...             28.822190
# 1_evals_registry/data/arithmetic/4_digit_additi...             32.021698
# 1_evals_registry/data/arithmetic/4_digit_subtra...             35.221375
# 1_evals_registry/data/arithmetic/4_digit_divisi...             38.444289
# 1_evals_registry/data/arithmetic/5_digit_multip...             41.696356
# 1_evals_registry/data/anli/samples.jsonl               3196.0
# 1_evals_registry/data/wanli/samples.jsonl              4996.0
# 1_evals_registry/data/babi_task_16/samples.jsonl       4996.0
# 1_evals_registry/data/cosmos_qa/samples.jsonl          2981.0
# 1_evals_registry/data/abstract_narrative_unders...      996.0
# 1_evals_registry/data/formal_fallacies_syllogis...    14196.0

# %% [markdown]
# # Compute the cost by keeping only a subset of samples for some dataset
#
# For some datasets, if I run on all samples, the cost is too high -> reduce the cost by keeping only 1000 samples for some of them

# %%
evals_cheap = ['odd_one_out',
 'crass_ai',
 'logical_args',
 'emoji_movie',
 'fantasy_reasoning',
 'metaphor_boolean',
 'geometric_shapes',
 'space_nli',
 'copa',
 'anli',
 'cosmos_qa',
 'ropes',
 'arithmetic']

# %%
len(evals_cheap)
# Out:
# 13

# %%
# extract all other evals that are not in evals_cheap
evals_expensive = list(set(DATASETS_DICT.keys()) - set(evals_cheap))

# %%
evals_expensive
# Out:
# ['formal_fallacies_syllogisms_negation',
#  'goal_step_wikihow',
#  'alpha_nli',
#  'babi_task_16',
#  'cause_and_effect',
#  'wanli',
#  'abstract_narrative_understanding']

# %% [markdown]
# ## Cost computation

# %%
# copy n_tokens_df and redefine the index with .split("data/")[1].split("/samples")[0].replace("/", "_") 
n_tokens_df_new_index = n_tokens_df.copy()
n_tokens_df_new_index.index = [i.split("data/")[1].split("/samples")[0].replace("/", "_") for i in n_tokens_df.index]

# %%
n_tokens_df_new_index
# Out:
#                                                  n_tokens  \
# arithmetic_1_digit_division                           703
# cause_and_effect_one_sentence_no_prompt              1457
# odd_one_out                                          2527
# cause_and_effect_two_sentences                       3015
# cause_and_effect_one_sentence                        3349
# arithmetic_1_digit_subtraction                       3456
# arithmetic_1_digit_addition                          3456
# arithmetic_1_digit_multiplication                    3456
# crass_ai                                             3965
# logical_args                                         5832
# arithmetic_2_digit_division                          7252
# emoji_movie                                          8381
# arithmetic_3_digit_division                         18678
# fantasy_reasoning                                   19308
# arithmetic_2_digit_multiplication                   35856
# arithmetic_2_digit_subtraction                      35856
# arithmetic_2_digit_addition                         35856
# arithmetic_3_digit_multiplication                   36931
# arithmetic_3_digit_addition                         36938
# arithmetic_3_digit_subtraction                      36971
# arithmetic_4_digit_multiplication                   37848
# arithmetic_4_digit_addition                         37864
# arithmetic_4_digit_subtraction                      37866
# arithmetic_4_digit_division                         38141
# arithmetic_5_digit_multiplication                   38486
# arithmetic_5_digit_addition                         38506
# arithmetic_5_digit_subtraction                      38517
# arithmetic_5_digit_division                         38699
# copa                                                47141
# metaphor_boolean                                    50229
# geometric_shapes                                    50669
# space_nli                                          139454
# goal_step_wikihow_goal_inference                   162936
# abstract_narrative_understanding_4_distractors     167283
# alpha_nli                                          182897
# ropes                                              217988
# abstract_narrative_understanding_9_distractors     219568
# goal_step_wikihow_step_inference                   235414
# goal_step_wikihow_step_ordering                    339987
# anli                                               487543
# wanli                                              490519
# babi_task_16                                       522312
# cosmos_qa                                          626367
# abstract_narrative_understanding_99_distractors   1141556
# formal_fallacies_syllogisms_negation              1936974
#
#                                                  cost_gpt-4-0125-preview  \
# arithmetic_1_digit_division                                      0.00703
# cause_and_effect_one_sentence_no_prompt                          0.01457
# odd_one_out                                                      0.02527
# cause_and_effect_two_sentences                                   0.03015
# cause_and_effect_one_sentence                                    0.03349
# arithmetic_1_digit_subtraction                                   0.03456
# arithmetic_1_digit_addition                                      0.03456
# arithmetic_1_digit_multiplication                                0.03456
# crass_ai                                                         0.03965
# logical_args                                                     0.05832
# arithmetic_2_digit_division                                      0.07252
# emoji_movie                                                      0.08381
# arithmetic_3_digit_division                                      0.18678
# fantasy_reasoning                                                0.19308
# arithmetic_2_digit_multiplication                                0.35856
# arithmetic_2_digit_subtraction                                   0.35856
# arithmetic_2_digit_addition                                      0.35856
# arithmetic_3_digit_multiplication                                0.36931
# arithmetic_3_digit_addition                                      0.36938
# arithmetic_3_digit_subtraction                                   0.36971
# arithmetic_4_digit_multiplication                                0.37848
# arithmetic_4_digit_addition                                      0.37864
# arithmetic_4_digit_subtraction                                   0.37866
# arithmetic_4_digit_division                                      0.38141
# arithmetic_5_digit_multiplication                                0.38486
# arithmetic_5_digit_addition                                      0.38506
# arithmetic_5_digit_subtraction                                   0.38517
# arithmetic_5_digit_division                                      0.38699
# copa                                                             0.47141
# metaphor_boolean                                                 0.50229
# geometric_shapes                                                 0.50669
# space_nli                                                        1.39454
# goal_step_wikihow_goal_inference                                 1.62936
# abstract_narrative_understanding_4_distractors                   1.67283
# alpha_nli                                                        1.82897
# ropes                                                            2.17988
# abstract_narrative_understanding_9_distractors                   2.19568
# goal_step_wikihow_step_inference                                 2.35414
# goal_step_wikihow_step_ordering                                  3.39987
# anli                                                             4.87543
# wanli                                                            4.90519
# babi_task_16                                                     5.22312
# cosmos_qa                                                        6.26367
# abstract_narrative_understanding_99_distractors                 11.41556
# formal_fallacies_syllogisms_negation                            19.36974
#
#                                                  cost_gpt-4-1106-preview  \
# arithmetic_1_digit_division                                      0.00703
# cause_and_effect_one_sentence_no_prompt                          0.01457
# odd_one_out                                                      0.02527
# cause_and_effect_two_sentences                                   0.03015
# cause_and_effect_one_sentence                                    0.03349
# arithmetic_1_digit_subtraction                                   0.03456
# arithmetic_1_digit_addition                                      0.03456
# arithmetic_1_digit_multiplication                                0.03456
# crass_ai                                                         0.03965
# logical_args                                                     0.05832
# arithmetic_2_digit_division                                      0.07252
# emoji_movie                                                      0.08381
# arithmetic_3_digit_division                                      0.18678
# fantasy_reasoning                                                0.19308
# arithmetic_2_digit_multiplication                                0.35856
# arithmetic_2_digit_subtraction                                   0.35856
# arithmetic_2_digit_addition                                      0.35856
# arithmetic_3_digit_multiplication                                0.36931
# arithmetic_3_digit_addition                                      0.36938
# arithmetic_3_digit_subtraction                                   0.36971
# arithmetic_4_digit_multiplication                                0.37848
# arithmetic_4_digit_addition                                      0.37864
# arithmetic_4_digit_subtraction                                   0.37866
# arithmetic_4_digit_division                                      0.38141
# arithmetic_5_digit_multiplication                                0.38486
# arithmetic_5_digit_addition                                      0.38506
# arithmetic_5_digit_subtraction                                   0.38517
# arithmetic_5_digit_division                                      0.38699
# copa                                                             0.47141
# metaphor_boolean                                                 0.50229
# geometric_shapes                                                 0.50669
# space_nli                                                        1.39454
# goal_step_wikihow_goal_inference                                 1.62936
# abstract_narrative_understanding_4_distractors                   1.67283
# alpha_nli                                                        1.82897
# ropes                                                            2.17988
# abstract_narrative_understanding_9_distractors                   2.19568
# goal_step_wikihow_step_inference                                 2.35414
# goal_step_wikihow_step_ordering                                  3.39987
# anli                                                             4.87543
# wanli                                                            4.90519
# babi_task_16                                                     5.22312
# cosmos_qa                                                        6.26367
# abstract_narrative_understanding_99_distractors                 11.41556
# formal_fallacies_syllogisms_negation                            19.36974
#
#                                                  cost_gpt-4-0613  \
# arithmetic_1_digit_division                              0.02109
# cause_and_effect_one_sentence_no_prompt                  0.04371
# odd_one_out                                              0.07581
# cause_and_effect_two_sentences                           0.09045
# cause_and_effect_one_sentence                            0.10047
# arithmetic_1_digit_subtraction                           0.10368
# arithmetic_1_digit_addition                              0.10368
# arithmetic_1_digit_multiplication                        0.10368
# crass_ai                                                 0.11895
# logical_args                                             0.17496
# arithmetic_2_digit_division                              0.21756
# emoji_movie                                              0.25143
# arithmetic_3_digit_division                              0.56034
# fantasy_reasoning                                        0.57924
# arithmetic_2_digit_multiplication                        1.07568
# arithmetic_2_digit_subtraction                           1.07568
# arithmetic_2_digit_addition                              1.07568
# arithmetic_3_digit_multiplication                        1.10793
# arithmetic_3_digit_addition                              1.10814
# arithmetic_3_digit_subtraction                           1.10913
# arithmetic_4_digit_multiplication                        1.13544
# arithmetic_4_digit_addition                              1.13592
# arithmetic_4_digit_subtraction                           1.13598
# arithmetic_4_digit_division                              1.14423
# arithmetic_5_digit_multiplication                        1.15458
# arithmetic_5_digit_addition                              1.15518
# arithmetic_5_digit_subtraction                           1.15551
# arithmetic_5_digit_division                              1.16097
# copa                                                     1.41423
# metaphor_boolean                                         1.50687
# geometric_shapes                                         1.52007
# space_nli                                                4.18362
# goal_step_wikihow_goal_inference                         4.88808
# abstract_narrative_understanding_4_distractors           5.01849
# alpha_nli                                                5.48691
# ropes                                                    6.53964
# abstract_narrative_understanding_9_distractors           6.58704
# goal_step_wikihow_step_inference                         7.06242
# goal_step_wikihow_step_ordering                         10.19961
# anli                                                    14.62629
# wanli                                                   14.71557
# babi_task_16                                            15.66936
# cosmos_qa                                               18.79101
# abstract_narrative_understanding_99_distractors         34.24668
# formal_fallacies_syllogisms_negation                    58.10922
#
#                                                  cost_gpt-4-0314  \
# arithmetic_1_digit_division                              0.02109
# cause_and_effect_one_sentence_no_prompt                  0.04371
# odd_one_out                                              0.07581
# cause_and_effect_two_sentences                           0.09045
# cause_and_effect_one_sentence                            0.10047
# arithmetic_1_digit_subtraction                           0.10368
# arithmetic_1_digit_addition                              0.10368
# arithmetic_1_digit_multiplication                        0.10368
# crass_ai                                                 0.11895
# logical_args                                             0.17496
# arithmetic_2_digit_division                              0.21756
# emoji_movie                                              0.25143
# arithmetic_3_digit_division                              0.56034
# fantasy_reasoning                                        0.57924
# arithmetic_2_digit_multiplication                        1.07568
# arithmetic_2_digit_subtraction                           1.07568
# arithmetic_2_digit_addition                              1.07568
# arithmetic_3_digit_multiplication                        1.10793
# arithmetic_3_digit_addition                              1.10814
# arithmetic_3_digit_subtraction                           1.10913
# arithmetic_4_digit_multiplication                        1.13544
# arithmetic_4_digit_addition                              1.13592
# arithmetic_4_digit_subtraction                           1.13598
# arithmetic_4_digit_division                              1.14423
# arithmetic_5_digit_multiplication                        1.15458
# arithmetic_5_digit_addition                              1.15518
# arithmetic_5_digit_subtraction                           1.15551
# arithmetic_5_digit_division                              1.16097
# copa                                                     1.41423
# metaphor_boolean                                         1.50687
# geometric_shapes                                         1.52007
# space_nli                                                4.18362
# goal_step_wikihow_goal_inference                         4.88808
# abstract_narrative_understanding_4_distractors           5.01849
# alpha_nli                                                5.48691
# ropes                                                    6.53964
# abstract_narrative_understanding_9_distractors           6.58704
# goal_step_wikihow_step_inference                         7.06242
# goal_step_wikihow_step_ordering                         10.19961
# anli                                                    14.62629
# wanli                                                   14.71557
# babi_task_16                                            15.66936
# cosmos_qa                                               18.79101
# abstract_narrative_understanding_99_distractors         34.24668
# formal_fallacies_syllogisms_negation                    58.10922
#
#                                                  cost_gpt-3.5-turbo-0125  \
# arithmetic_1_digit_division                                     0.000351
# cause_and_effect_one_sentence_no_prompt                         0.000728
# odd_one_out                                                     0.001263
# cause_and_effect_two_sentences                                  0.001507
# cause_and_effect_one_sentence                                   0.001674
# arithmetic_1_digit_subtraction                                  0.001728
# arithmetic_1_digit_addition                                     0.001728
# arithmetic_1_digit_multiplication                               0.001728
# crass_ai                                                        0.001982
# logical_args                                                    0.002916
# arithmetic_2_digit_division                                     0.003626
# emoji_movie                                                     0.004190
# arithmetic_3_digit_division                                     0.009339
# fantasy_reasoning                                               0.009654
# arithmetic_2_digit_multiplication                               0.017928
# arithmetic_2_digit_subtraction                                  0.017928
# arithmetic_2_digit_addition                                     0.017928
# arithmetic_3_digit_multiplication                               0.018465
# arithmetic_3_digit_addition                                     0.018469
# arithmetic_3_digit_subtraction                                  0.018485
# arithmetic_4_digit_multiplication                               0.018924
# arithmetic_4_digit_addition                                     0.018932
# arithmetic_4_digit_subtraction                                  0.018933
# arithmetic_4_digit_division                                     0.019071
# arithmetic_5_digit_multiplication                               0.019243
# arithmetic_5_digit_addition                                     0.019253
# arithmetic_5_digit_subtraction                                  0.019258
# arithmetic_5_digit_division                                     0.019349
# copa                                                            0.023570
# metaphor_boolean                                                0.025114
# geometric_shapes                                                0.025334
# space_nli                                                       0.069727
# goal_step_wikihow_goal_inference                                0.081468
# abstract_narrative_understanding_4_distractors                  0.083641
# alpha_nli                                                       0.091449
# ropes                                                           0.108994
# abstract_narrative_understanding_9_distractors                  0.109784
# goal_step_wikihow_step_inference                                0.117707
# goal_step_wikihow_step_ordering                                 0.169993
# anli                                                            0.243772
# wanli                                                           0.245259
# babi_task_16                                                    0.261156
# cosmos_qa                                                       0.313184
# abstract_narrative_understanding_99_distractors                 0.570778
# formal_fallacies_syllogisms_negation                            0.968487
#
#                                                  cost_gpt-3.5-turbo-1106  \
# arithmetic_1_digit_division                                     0.000703
# cause_and_effect_one_sentence_no_prompt                         0.001457
# odd_one_out                                                     0.002527
# cause_and_effect_two_sentences                                  0.003015
# cause_and_effect_one_sentence                                   0.003349
# arithmetic_1_digit_subtraction                                  0.003456
# arithmetic_1_digit_addition                                     0.003456
# arithmetic_1_digit_multiplication                               0.003456
# crass_ai                                                        0.003965
# logical_args                                                    0.005832
# arithmetic_2_digit_division                                     0.007252
# emoji_movie                                                     0.008381
# arithmetic_3_digit_division                                     0.018678
# fantasy_reasoning                                               0.019308
# arithmetic_2_digit_multiplication                               0.035856
# arithmetic_2_digit_subtraction                                  0.035856
# arithmetic_2_digit_addition                                     0.035856
# arithmetic_3_digit_multiplication                               0.036931
# arithmetic_3_digit_addition                                     0.036938
# arithmetic_3_digit_subtraction                                  0.036971
# arithmetic_4_digit_multiplication                               0.037848
# arithmetic_4_digit_addition                                     0.037864
# arithmetic_4_digit_subtraction                                  0.037866
# arithmetic_4_digit_division                                     0.038141
# arithmetic_5_digit_multiplication                               0.038486
# arithmetic_5_digit_addition                                     0.038506
# arithmetic_5_digit_subtraction                                  0.038517
# arithmetic_5_digit_division                                     0.038699
# copa                                                            0.047141
# metaphor_boolean                                                0.050229
# geometric_shapes                                                0.050669
# space_nli                                                       0.139454
# goal_step_wikihow_goal_inference                                0.162936
# abstract_narrative_understanding_4_distractors                  0.167283
# alpha_nli                                                       0.182897
# ropes                                                           0.217988
# abstract_narrative_understanding_9_distractors                  0.219568
# goal_step_wikihow_step_inference                                0.235414
# goal_step_wikihow_step_ordering                                 0.339987
# anli                                                            0.487543
# wanli                                                           0.490519
# babi_task_16                                                    0.522312
# cosmos_qa                                                       0.626367
# abstract_narrative_understanding_99_distractors                 1.141556
# formal_fallacies_syllogisms_negation                            1.936974
#
#                                                  cost_gpt-3.5-turbo-0613  \
# arithmetic_1_digit_division                                     0.001055
# cause_and_effect_one_sentence_no_prompt                         0.002185
# odd_one_out                                                     0.003791
# cause_and_effect_two_sentences                                  0.004523
# cause_and_effect_one_sentence                                   0.005024
# arithmetic_1_digit_subtraction                                  0.005184
# arithmetic_1_digit_addition                                     0.005184
# arithmetic_1_digit_multiplication                               0.005184
# crass_ai                                                        0.005948
# logical_args                                                    0.008748
# arithmetic_2_digit_division                                     0.010878
# emoji_movie                                                     0.012572
# arithmetic_3_digit_division                                     0.028017
# fantasy_reasoning                                               0.028962
# arithmetic_2_digit_multiplication                               0.053784
# arithmetic_2_digit_subtraction                                  0.053784
# arithmetic_2_digit_addition                                     0.053784
# arithmetic_3_digit_multiplication                               0.055397
# arithmetic_3_digit_addition                                     0.055407
# arithmetic_3_digit_subtraction                                  0.055456
# arithmetic_4_digit_multiplication                               0.056772
# arithmetic_4_digit_addition                                     0.056796
# arithmetic_4_digit_subtraction                                  0.056799
# arithmetic_4_digit_division                                     0.057211
# arithmetic_5_digit_multiplication                               0.057729
# arithmetic_5_digit_addition                                     0.057759
# arithmetic_5_digit_subtraction                                  0.057776
# arithmetic_5_digit_division                                     0.058049
# copa                                                            0.070711
# metaphor_boolean                                                0.075344
# geometric_shapes                                                0.076004
# space_nli                                                       0.209181
# goal_step_wikihow_goal_inference                                0.244404
# abstract_narrative_understanding_4_distractors                  0.250924
# alpha_nli                                                       0.274346
# ropes                                                           0.326982
# abstract_narrative_understanding_9_distractors                  0.329352
# goal_step_wikihow_step_inference                                0.353121
# goal_step_wikihow_step_ordering                                 0.509981
# anli                                                            0.731314
# wanli                                                           0.735779
# babi_task_16                                                    0.783468
# cosmos_qa                                                       0.939551
# abstract_narrative_understanding_99_distractors                 1.712334
# formal_fallacies_syllogisms_negation                            2.905461
#
#                                                  cost_gpt-3.5-turbo-0301  \
# arithmetic_1_digit_division                                     0.001055
# cause_and_effect_one_sentence_no_prompt                         0.002185
# odd_one_out                                                     0.003791
# cause_and_effect_two_sentences                                  0.004523
# cause_and_effect_one_sentence                                   0.005024
# arithmetic_1_digit_subtraction                                  0.005184
# arithmetic_1_digit_addition                                     0.005184
# arithmetic_1_digit_multiplication                               0.005184
# crass_ai                                                        0.005948
# logical_args                                                    0.008748
# arithmetic_2_digit_division                                     0.010878
# emoji_movie                                                     0.012572
# arithmetic_3_digit_division                                     0.028017
# fantasy_reasoning                                               0.028962
# arithmetic_2_digit_multiplication                               0.053784
# arithmetic_2_digit_subtraction                                  0.053784
# arithmetic_2_digit_addition                                     0.053784
# arithmetic_3_digit_multiplication                               0.055397
# arithmetic_3_digit_addition                                     0.055407
# arithmetic_3_digit_subtraction                                  0.055456
# arithmetic_4_digit_multiplication                               0.056772
# arithmetic_4_digit_addition                                     0.056796
# arithmetic_4_digit_subtraction                                  0.056799
# arithmetic_4_digit_division                                     0.057211
# arithmetic_5_digit_multiplication                               0.057729
# arithmetic_5_digit_addition                                     0.057759
# arithmetic_5_digit_subtraction                                  0.057776
# arithmetic_5_digit_division                                     0.058049
# copa                                                            0.070711
# metaphor_boolean                                                0.075344
# geometric_shapes                                                0.076004
# space_nli                                                       0.209181
# goal_step_wikihow_goal_inference                                0.244404
# abstract_narrative_understanding_4_distractors                  0.250924
# alpha_nli                                                       0.274346
# ropes                                                           0.326982
# abstract_narrative_understanding_9_distractors                  0.329352
# goal_step_wikihow_step_inference                                0.353121
# goal_step_wikihow_step_ordering                                 0.509981
# anli                                                            0.731314
# wanli                                                           0.735779
# babi_task_16                                                    0.783468
# cosmos_qa                                                       0.939551
# abstract_narrative_understanding_99_distractors                 1.712334
# formal_fallacies_syllogisms_negation                            2.905461
#
#                                                  total_cost  n_samples  \
# arithmetic_1_digit_division                        0.059403       19.0
# cause_and_effect_one_sentence_no_prompt            0.123116       47.0
# odd_one_out                                        0.213532       82.0
# cause_and_effect_two_sentences                     0.254767       47.0
# cause_and_effect_one_sentence                      0.282991       47.0
# arithmetic_1_digit_subtraction                     0.292032       96.0
# arithmetic_1_digit_addition                        0.292032       96.0
# arithmetic_1_digit_multiplication                  0.292032       96.0
# crass_ai                                           0.335043       40.0
# logical_args                                       0.492804       28.0
# arithmetic_2_digit_division                        0.612794      196.0
# emoji_movie                                        0.708194       96.0
# arithmetic_3_digit_division                        1.578291      496.0
# fantasy_reasoning                                  1.631526      197.0
# arithmetic_2_digit_multiplication                  3.029832      996.0
# arithmetic_2_digit_subtraction                     3.029832      996.0
# arithmetic_2_digit_addition                        3.029832      996.0
# arithmetic_3_digit_multiplication                  3.120670      996.0
# arithmetic_3_digit_addition                        3.121261      996.0
# arithmetic_3_digit_subtraction                     3.124049      996.0
# arithmetic_4_digit_multiplication                  3.198156      996.0
# arithmetic_4_digit_addition                        3.199508      996.0
# arithmetic_4_digit_subtraction                     3.199677      996.0
# arithmetic_4_digit_division                        3.222915      996.0
# arithmetic_5_digit_multiplication                  3.252067      996.0
# arithmetic_5_digit_addition                        3.253757      996.0
# arithmetic_5_digit_subtraction                     3.254687      996.0
# arithmetic_5_digit_division                        3.270066      996.0
# copa                                               3.983414      496.0
# metaphor_boolean                                   4.244350      676.0
# geometric_shapes                                   4.281530      356.0
# space_nli                                         11.783863     1600.0
# goal_step_wikihow_goal_inference                  13.768092     1699.0
# abstract_narrative_understanding_4_distractors    14.135414      996.0
# alpha_nli                                         15.454797     1528.0
# ropes                                             18.419986     1684.0
# abstract_narrative_understanding_9_distractors    18.553496      996.0
# goal_step_wikihow_step_inference                  19.892483     2246.0
# goal_step_wikihow_step_ordering                   28.728902     3096.0
# anli                                              41.197384     3196.0
# wanli                                             41.448856     4996.0
# babi_task_16                                      44.135364     4996.0
# cosmos_qa                                         52.928012     2981.0
# abstract_narrative_understanding_99_distractors   96.461482      996.0
# formal_fallacies_syllogisms_negation             163.674303    14196.0
#
#                                                  cumsum_cost_instruct  \
# arithmetic_1_digit_division                                  0.059403
# cause_and_effect_one_sentence_no_prompt                      0.182520
# odd_one_out                                                  0.396052
# cause_and_effect_two_sentences                               0.650819
# cause_and_effect_one_sentence                                0.933810
# arithmetic_1_digit_subtraction                               1.225842
# arithmetic_1_digit_addition                                  1.517874
# arithmetic_1_digit_multiplication                            1.809906
# crass_ai                                                     2.144948
# logical_args                                                 2.637752
# arithmetic_2_digit_division                                  3.250546
# emoji_movie                                                  3.958741
# arithmetic_3_digit_division                                  5.537032
# fantasy_reasoning                                            7.168558
# arithmetic_2_digit_multiplication                           10.198389
# arithmetic_2_digit_subtraction                              13.228221
# arithmetic_2_digit_addition                                 16.258053
# arithmetic_3_digit_multiplication                           19.378723
# arithmetic_3_digit_addition                                 22.499984
# arithmetic_3_digit_subtraction                              25.624034
# arithmetic_4_digit_multiplication                           28.822190
# arithmetic_4_digit_addition                                 32.021698
# arithmetic_4_digit_subtraction                              35.221375
# arithmetic_4_digit_division                                 38.444289
# arithmetic_5_digit_multiplication                           41.696356
# arithmetic_5_digit_addition                                 44.950113
# arithmetic_5_digit_subtraction                              48.204800
# arithmetic_5_digit_division                                 51.474865
# copa                                                        55.458280
# metaphor_boolean                                            59.702630
# geometric_shapes                                            63.984161
# space_nli                                                   75.768023
# goal_step_wikihow_goal_inference                            89.536115
# abstract_narrative_understanding_4_distractors             103.671529
# alpha_nli                                                  119.126325
# ropes                                                      137.546312
# abstract_narrative_understanding_9_distractors             156.099807
# goal_step_wikihow_step_inference                           175.992290
# goal_step_wikihow_step_ordering                            204.721192
# anli                                                       245.918576
# wanli                                                      287.367431
# babi_task_16                                               331.502795
# cosmos_qa                                                  384.430807
# abstract_narrative_understanding_99_distractors            480.892289
# formal_fallacies_syllogisms_negation                       644.566591
#
#                                                  cumsum_n_samples
# arithmetic_1_digit_division                                  19.0
# cause_and_effect_one_sentence_no_prompt                      66.0
# odd_one_out                                                 148.0
# cause_and_effect_two_sentences                              195.0
# cause_and_effect_one_sentence                               242.0
# arithmetic_1_digit_subtraction                              338.0
# arithmetic_1_digit_addition                                 434.0
# arithmetic_1_digit_multiplication                           530.0
# crass_ai                                                    570.0
# logical_args                                                598.0
# arithmetic_2_digit_division                                 794.0
# emoji_movie                                                 890.0
# arithmetic_3_digit_division                                1386.0
# fantasy_reasoning                                          1583.0
# arithmetic_2_digit_multiplication                          2579.0
# arithmetic_2_digit_subtraction                             3575.0
# arithmetic_2_digit_addition                                4571.0
# arithmetic_3_digit_multiplication                          5567.0
# arithmetic_3_digit_addition                                6563.0
# arithmetic_3_digit_subtraction                             7559.0
# arithmetic_4_digit_multiplication                          8555.0
# arithmetic_4_digit_addition                                9551.0
# arithmetic_4_digit_subtraction                            10547.0
# arithmetic_4_digit_division                               11543.0
# arithmetic_5_digit_multiplication                         12539.0
# arithmetic_5_digit_addition                               13535.0
# arithmetic_5_digit_subtraction                            14531.0
# arithmetic_5_digit_division                               15527.0
# copa                                                      16023.0
# metaphor_boolean                                          16699.0
# geometric_shapes                                          17055.0
# space_nli                                                 18655.0
# goal_step_wikihow_goal_inference                          20354.0
# abstract_narrative_understanding_4_distractors            21350.0
# alpha_nli                                                 22878.0
# ropes                                                     24562.0
# abstract_narrative_understanding_9_distractors            25558.0
# goal_step_wikihow_step_inference                          27804.0
# goal_step_wikihow_step_ordering                           30900.0
# anli                                                      34096.0
# wanli                                                     39092.0
# babi_task_16                                              44088.0
# cosmos_qa                                                 47069.0
# abstract_narrative_understanding_99_distractors           48065.0
# formal_fallacies_syllogisms_negation                      62261.0

# %%
# compute the total cost with 1000 samples
n_tokens_df_new_index["total_cost_1000"] = n_tokens_df_new_index.apply(lambda x: x["total_cost"]/x["n_samples"] * 1000, axis=1)

# %%
# total cost of the cheap evals on instruct and base models
# loop over rows and check if index startswith a cheapeval
# total cost of the cheap evals on instruct and base models
total_cost_cheap = 0
for index, row in n_tokens_df_new_index.iterrows():
    if any(index.startswith(eval) for eval in evals_cheap):
        total_cost_cheap += row["total_cost"]

print(f"Total cost of cheap evals on instruct and base models: {total_cost_cheap:.2f}")
# Out:
# Total cost of cheap evals on instruct and base models: 187.65

# %%
# total cost of the expensive evals on instruct and base models
# loop over rows and check if index startswith a expensiveeval
# total cost of the expensive evals on instruct and base models
total_cost_expensive = 0
for index, row in n_tokens_df_new_index.iterrows():
    if any(index.startswith(eval) for eval in evals_expensive):
        total_cost_expensive += row["total_cost_1000"]

print(f"Total cost of expensive evals on instruct and base models: {total_cost_expensive:.2f}")
# Out:
# Total cost of expensive evals on instruct and base models: 208.74

# %%
grand_total = total_cost_cheap  + total_cost_expensive
print(f"Grand total: {grand_total:.2f}")
# Out:
# Grand total: 396.40
