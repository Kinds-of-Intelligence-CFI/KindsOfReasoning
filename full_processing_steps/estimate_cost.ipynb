# %% [markdown]
# # Estimate cost of running a model on the KindsOfReasoning dataset

# %%
import pandas as pd

from set_up_datasets import DATASETS_DICT
from src.utils import compute_n_tokens, compute_cost

# enable reloading of modules
# %load_ext autoreload
# %autoreload 2

# %%
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# Out:
# /home/lorenzo/venv/recog-LLM_capabilities/lib/python3.9/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
DATASETS_DICT
# Out:
# {'space_nli': set_up_datasets.SpaceNLI,
#  'anli': set_up_datasets.ANLI,
#  'copa': set_up_datasets.COPA,
#  'alpha_nli': set_up_datasets.AlphaNLI,
#  'wanli': set_up_datasets.WANLI,
#  'babi_task_16': set_up_datasets.bABItask16,
#  'ropes': set_up_datasets.ROPES,
#  'cosmos_qa': set_up_datasets.CosmosQA,
#  'formal_fallacies_syllogisms_negation': set_up_datasets.FormalFallaciesSyllogismsNegation,
#  'logical_args': set_up_datasets.LogicalArgs,
#  'crass_ai': set_up_datasets.CrassAI,
#  'geometric_shapes': set_up_datasets.GeometricShapes,
#  'emoji_movie': set_up_datasets.EmojiMovie,
#  'odd_one_out': set_up_datasets.OddOneOut,
#  'metaphor_boolean': set_up_datasets.MetaphorBoolean,
#  'fantasy_reasoning': set_up_datasets.FantasyReasoning,
#  'abstract_narrative_understanding': set_up_datasets.AbstractNarrativeUnderstanding,
#  'cause_and_effect': set_up_datasets.CauseAndEffect,
#  'goal_step_wikihow': set_up_datasets.GoalStepWikihow,
#  'arithmetic': set_up_datasets.Arithmetic}

# %%
len(DATASETS_DICT)
# Out:
# 20

# %% [markdown]
# # Extract the number of tokens for each dataset and the cost per model

# %% [markdown]
# ## Compute the number of tokens

# %%
registry_path = "1_registry"

n_tokens_dict = {}
for dataset_id, dataset_class in DATASETS_DICT.items():
        
    # print(dataset_id)
    dataset = dataset_class()
    
    if hasattr(dataset, "subtasks") and dataset.subtasks is not None:
        subtasks = dataset.subtasks
        if not isinstance(subtasks, list):
            subtasks = [subtasks]
        
        filepath_list  = [dataset._get_samples_path(registry_path,subtask=subtask) for subtask in subtasks]
        # print(filepath_list)
    else:
        filepath_list = [dataset._get_samples_path(registry_path)]
        # print(filepath_list)
        
    # load the dataframe
    for filepath in filepath_list:
        print(filepath)
        original_df = pd.read_json(filepath, lines=True)
        original_df["n_tokens"] = original_df["input"].apply(
    lambda x: compute_n_tokens("System: " + x[0]["content"] + "\nUser: " + x[1]["content"] + "\nAnswer: ", tokenizer))
        print(filepath, len(original_df))
        n_tokens_dict[filepath] = original_df["n_tokens"].sum()
total_n_tokens = sum(n_tokens_dict.values())
# Out:
# 1_registry/data/space_nli/samples.jsonl
# 1_registry/data/space_nli/samples.jsonl 1600
# 1_registry/data/anli/samples.jsonl
# 1_registry/data/anli/samples.jsonl 3196
# 1_registry/data/copa/samples.jsonl
# 1_registry/data/copa/samples.jsonl 496
# 1_registry/data/alpha_nli/samples.jsonl
# 1_registry/data/alpha_nli/samples.jsonl 1528
# 1_registry/data/wanli/samples.jsonl
# 1_registry/data/wanli/samples.jsonl 4996
# 1_registry/data/babi_task_16/samples.jsonl
# 1_registry/data/babi_task_16/samples.jsonl 4996
# 1_registry/data/ropes/samples.jsonl
# 1_registry/data/ropes/samples.jsonl 1684
# 1_registry/data/cosmos_qa/samples.jsonl
# 1_registry/data/cosmos_qa/samples.jsonl 2981
# 1_registry/data/formal_fallacies_syllogisms_negation/samples.jsonl
# 1_registry/data/formal_fallacies_syllogisms_negation/samples.jsonl 14196
# 1_registry/data/logical_args/samples.jsonl
# 1_registry/data/logical_args/samples.jsonl 28
# 1_registry/data/crass_ai/samples.jsonl
# 1_registry/data/crass_ai/samples.jsonl 40
# 1_registry/data/geometric_shapes/samples.jsonl
# 1_registry/data/geometric_shapes/samples.jsonl 356
# 1_registry/data/emoji_movie/samples.jsonl
# 1_registry/data/emoji_movie/samples.jsonl 96
# 1_registry/data/odd_one_out/samples.jsonl
# 1_registry/data/odd_one_out/samples.jsonl 82
# 1_registry/data/metaphor_boolean/samples.jsonl
# 1_registry/data/metaphor_boolean/samples.jsonl 676
# 1_registry/data/fantasy_reasoning/samples.jsonl
# 1_registry/data/fantasy_reasoning/samples.jsonl 197
# 1_registry/data/abstract_narrative_understanding/4_distractors/samples.jsonl
# 1_registry/data/abstract_narrative_understanding/4_distractors/samples.jsonl 996
# 1_registry/data/abstract_narrative_understanding/9_distractors/samples.jsonl
# Token indices sequence length is longer than the specified maximum sequence length for this model (1131 > 1024). Running this sequence through the model will result in indexing errors
# 1_registry/data/abstract_narrative_understanding/9_distractors/samples.jsonl 996
# 1_registry/data/abstract_narrative_understanding/99_distractors/samples.jsonl
# 1_registry/data/abstract_narrative_understanding/99_distractors/samples.jsonl 996
# 1_registry/data/cause_and_effect/one_sentence/samples.jsonl
# 1_registry/data/cause_and_effect/one_sentence/samples.jsonl 47
# 1_registry/data/cause_and_effect/one_sentence_no_prompt/samples.jsonl
# 1_registry/data/cause_and_effect/one_sentence_no_prompt/samples.jsonl 47
# 1_registry/data/cause_and_effect/two_sentences/samples.jsonl
# 1_registry/data/cause_and_effect/two_sentences/samples.jsonl 47
# 1_registry/data/goal_step_wikihow/goal_inference/samples.jsonl
# 1_registry/data/goal_step_wikihow/goal_inference/samples.jsonl 1699
# 1_registry/data/goal_step_wikihow/step_inference/samples.jsonl
# 1_registry/data/goal_step_wikihow/step_inference/samples.jsonl 2246
# 1_registry/data/goal_step_wikihow/step_ordering/samples.jsonl
# 1_registry/data/goal_step_wikihow/step_ordering/samples.jsonl 3096
# 1_registry/data/arithmetic/1_digit_addition/samples.jsonl
# 1_registry/data/arithmetic/1_digit_addition/samples.jsonl 96
# 1_registry/data/arithmetic/2_digit_addition/samples.jsonl
# 1_registry/data/arithmetic/2_digit_addition/samples.jsonl 996
# 1_registry/data/arithmetic/3_digit_addition/samples.jsonl
# 1_registry/data/arithmetic/3_digit_addition/samples.jsonl 996
# 1_registry/data/arithmetic/4_digit_addition/samples.jsonl
# 1_registry/data/arithmetic/4_digit_addition/samples.jsonl 996
# 1_registry/data/arithmetic/5_digit_addition/samples.jsonl
# 1_registry/data/arithmetic/5_digit_addition/samples.jsonl 996
# 1_registry/data/arithmetic/1_digit_subtraction/samples.jsonl
# 1_registry/data/arithmetic/1_digit_subtraction/samples.jsonl 96
# 1_registry/data/arithmetic/2_digit_subtraction/samples.jsonl
# 1_registry/data/arithmetic/2_digit_subtraction/samples.jsonl 996
# 1_registry/data/arithmetic/3_digit_subtraction/samples.jsonl
# 1_registry/data/arithmetic/3_digit_subtraction/samples.jsonl 996
# 1_registry/data/arithmetic/4_digit_subtraction/samples.jsonl
# 1_registry/data/arithmetic/4_digit_subtraction/samples.jsonl 996
# 1_registry/data/arithmetic/5_digit_subtraction/samples.jsonl
# 1_registry/data/arithmetic/5_digit_subtraction/samples.jsonl 996
# 1_registry/data/arithmetic/1_digit_multiplication/samples.jsonl
# 1_registry/data/arithmetic/1_digit_multiplication/samples.jsonl 96
# 1_registry/data/arithmetic/2_digit_multiplication/samples.jsonl
# 1_registry/data/arithmetic/2_digit_multiplication/samples.jsonl 996
# 1_registry/data/arithmetic/3_digit_multiplication/samples.jsonl
# 1_registry/data/arithmetic/3_digit_multiplication/samples.jsonl 996
# 1_registry/data/arithmetic/4_digit_multiplication/samples.jsonl
# 1_registry/data/arithmetic/4_digit_multiplication/samples.jsonl 996
# 1_registry/data/arithmetic/5_digit_multiplication/samples.jsonl
# 1_registry/data/arithmetic/5_digit_multiplication/samples.jsonl 996
# 1_registry/data/arithmetic/1_digit_division/samples.jsonl
# 1_registry/data/arithmetic/1_digit_division/samples.jsonl 19
# 1_registry/data/arithmetic/2_digit_division/samples.jsonl
# 1_registry/data/arithmetic/2_digit_division/samples.jsonl 196
# 1_registry/data/arithmetic/3_digit_division/samples.jsonl
# 1_registry/data/arithmetic/3_digit_division/samples.jsonl 496
# 1_registry/data/arithmetic/4_digit_division/samples.jsonl
# 1_registry/data/arithmetic/4_digit_division/samples.jsonl 996
# 1_registry/data/arithmetic/5_digit_division/samples.jsonl
# 1_registry/data/arithmetic/5_digit_division/samples.jsonl 996

# %% [markdown]
# ## Compute the cost per model

# %%
models_to_evaluate = ["gpt-4-0125-preview", "gpt-4-1106-preview", "gpt-4-0613", "gpt-4-0314",
"gpt-3.5-turbo-0125", "gpt-3.5-turbo-1106", "gpt-3.5-turbo-0613", "gpt-3.5-turbo-0301",]
models_to_evaluate =  ["gpt-4o-2024-08-06",
    "gpt-4o-2024-05-13",
    "gpt-4o-mini-2024-07-18",
    "gpt-4-turbo-2024-04-09",]

# %%
total_cost = 0
for model_id in models_to_evaluate:
    print(f"Cost for {model_id}: {compute_cost(model_id, total_n_tokens):.2f}")
    total_cost += compute_cost(model_id, total_n_tokens)
print(f"Total cost: {total_cost:.2f}")
# Out:
# Cost for gpt-4o-2024-08-06: 19.07
# Cost for gpt-4o-2024-05-13: 38.14
# Cost for gpt-4o-mini-2024-07-18: 1.14
# Cost for gpt-4-turbo-2024-04-09: 76.28
# Total cost: 134.63

# %%
# convert n_tokens_dict to a dataframe
n_tokens_df = pd.DataFrame.from_dict(n_tokens_dict, orient="index", columns=["n_tokens"])

# %%
# add the cost
for model_id in models_to_evaluate:
    n_tokens_df[f"cost_{model_id}"] = n_tokens_df["n_tokens"].apply(lambda x: compute_cost(model_id, x))
n_tokens_df["total_cost"] = n_tokens_df[[f"cost_{model_id}" for model_id in models_to_evaluate]].sum(axis=1)

# %%
# add the number of samples in each row
for filepath in n_tokens_df.index:
    original_df = pd.read_json(filepath, lines=True)
    n_tokens_df.loc[filepath, "n_samples"] = len(original_df)

# %%
n_tokens_df = n_tokens_df.sort_values(by="total_cost", ascending=True)

# %%
n_tokens_df.head()
# Out:
#                                                     n_tokens  \
# 1_registry/data/arithmetic/1_digit_division/sam...       703
# 1_registry/data/cause_and_effect/one_sentence_n...      1457
# 1_registry/data/odd_one_out/samples.jsonl               2527
# 1_registry/data/cause_and_effect/two_sentences/...      3015
# 1_registry/data/cause_and_effect/one_sentence/s...      3349
#
#                                                     cost_gpt-4o-2024-08-06  \
# 1_registry/data/arithmetic/1_digit_division/sam...                0.001758
# 1_registry/data/cause_and_effect/one_sentence_n...                0.003643
# 1_registry/data/odd_one_out/samples.jsonl                         0.006318
# 1_registry/data/cause_and_effect/two_sentences/...                0.007538
# 1_registry/data/cause_and_effect/one_sentence/s...                0.008373
#
#                                                     cost_gpt-4o-2024-05-13  \
# 1_registry/data/arithmetic/1_digit_division/sam...                0.003515
# 1_registry/data/cause_and_effect/one_sentence_n...                0.007285
# 1_registry/data/odd_one_out/samples.jsonl                         0.012635
# 1_registry/data/cause_and_effect/two_sentences/...                0.015075
# 1_registry/data/cause_and_effect/one_sentence/s...                0.016745
#
#                                                     cost_gpt-4o-mini-2024-07-18  \
# 1_registry/data/arithmetic/1_digit_division/sam...                     0.000105
# 1_registry/data/cause_and_effect/one_sentence_n...                     0.000219
# 1_registry/data/odd_one_out/samples.jsonl                              0.000379
# 1_registry/data/cause_and_effect/two_sentences/...                     0.000452
# 1_registry/data/cause_and_effect/one_sentence/s...                     0.000502
#
#                                                     cost_gpt-4-turbo-2024-04-09  \
# 1_registry/data/arithmetic/1_digit_division/sam...                      0.00703
# 1_registry/data/cause_and_effect/one_sentence_n...                      0.01457
# 1_registry/data/odd_one_out/samples.jsonl                               0.02527
# 1_registry/data/cause_and_effect/two_sentences/...                      0.03015
# 1_registry/data/cause_and_effect/one_sentence/s...                      0.03349
#
#                                                     total_cost  n_samples
# 1_registry/data/arithmetic/1_digit_division/sam...    0.012408       19.0
# 1_registry/data/cause_and_effect/one_sentence_n...    0.025716       47.0
# 1_registry/data/odd_one_out/samples.jsonl             0.044602       82.0
# 1_registry/data/cause_and_effect/two_sentences/...    0.053215       47.0
# 1_registry/data/cause_and_effect/one_sentence/s...    0.059110       47.0

# %%
n_tokens_df[["total_cost"]]
# Out:
#                                                     total_cost
# 1_registry/data/arithmetic/1_digit_division/sam...    0.012408
# 1_registry/data/cause_and_effect/one_sentence_n...    0.025716
# 1_registry/data/odd_one_out/samples.jsonl             0.044602
# 1_registry/data/cause_and_effect/two_sentences/...    0.053215
# 1_registry/data/cause_and_effect/one_sentence/s...    0.059110
# 1_registry/data/arithmetic/1_digit_subtraction/...    0.060998
# 1_registry/data/arithmetic/1_digit_addition/sam...    0.060998
# 1_registry/data/arithmetic/1_digit_multiplicati...    0.060998
# 1_registry/data/crass_ai/samples.jsonl                0.069982
# 1_registry/data/logical_args/samples.jsonl            0.102935
# 1_registry/data/arithmetic/2_digit_division/sam...    0.127998
# 1_registry/data/emoji_movie/samples.jsonl             0.147925
# 1_registry/data/arithmetic/3_digit_division/sam...    0.329667
# 1_registry/data/fantasy_reasoning/samples.jsonl       0.340786
# 1_registry/data/arithmetic/2_digit_multiplicati...    0.632858
# 1_registry/data/arithmetic/2_digit_subtraction/...    0.632858
# 1_registry/data/arithmetic/2_digit_addition/sam...    0.632858
# 1_registry/data/arithmetic/3_digit_multiplicati...    0.651832
# 1_registry/data/arithmetic/3_digit_addition/sam...    0.651956
# 1_registry/data/arithmetic/3_digit_subtraction/...    0.652538
# 1_registry/data/arithmetic/4_digit_multiplicati...    0.668017
# 1_registry/data/arithmetic/4_digit_addition/sam...    0.668300
# 1_registry/data/arithmetic/4_digit_subtraction/...    0.668335
# 1_registry/data/arithmetic/4_digit_division/sam...    0.673189
# 1_registry/data/arithmetic/5_digit_multiplicati...    0.679278
# 1_registry/data/arithmetic/5_digit_addition/sam...    0.679631
# 1_registry/data/arithmetic/5_digit_subtraction/...    0.679825
# 1_registry/data/arithmetic/5_digit_division/sam...    0.683037
# 1_registry/data/copa/samples.jsonl                    0.832039
# 1_registry/data/metaphor_boolean/samples.jsonl        0.886542
# 1_registry/data/geometric_shapes/samples.jsonl        0.894308
# 1_registry/data/space_nli/samples.jsonl               2.461363
# 1_registry/data/goal_step_wikihow/goal_inferenc...    2.875820
# 1_registry/data/abstract_narrative_understandin...    2.952545
# 1_registry/data/alpha_nli/samples.jsonl               3.228132
# 1_registry/data/ropes/samples.jsonl                   3.847488
# 1_registry/data/abstract_narrative_understandin...    3.875375
# 1_registry/data/goal_step_wikihow/step_inferenc...    4.155057
# 1_registry/data/goal_step_wikihow/step_ordering...    6.000771
# 1_registry/data/anli/samples.jsonl                    8.605134
# 1_registry/data/wanli/samples.jsonl                   8.657660
# 1_registry/data/babi_task_16/samples.jsonl            9.218807
# 1_registry/data/cosmos_qa/samples.jsonl              11.055378
# 1_registry/data/abstract_narrative_understandin...   20.148463
# 1_registry/data/formal_fallacies_syllogisms_neg...   34.187591

# %% [markdown]
# cumsum

# %%
n_tokens_df["cumsum_cost_instruct"] = n_tokens_df["total_cost"].cumsum()
n_tokens_df["cumsum_n_samples"] = n_tokens_df["n_samples"].cumsum()

# %%
n_tokens_df[["cumsum_cost_instruct", "total_cost", "cumsum_n_samples", "n_samples"]]
# Out:
#                                                     cumsum_cost_instruct  \
# 1_registry/data/arithmetic/1_digit_division/sam...              0.012408
# 1_registry/data/cause_and_effect/one_sentence_n...              0.038124
# 1_registry/data/odd_one_out/samples.jsonl                       0.082726
# 1_registry/data/cause_and_effect/two_sentences/...              0.135940
# 1_registry/data/cause_and_effect/one_sentence/s...              0.195050
# 1_registry/data/arithmetic/1_digit_subtraction/...              0.256049
# 1_registry/data/arithmetic/1_digit_addition/sam...              0.317047
# 1_registry/data/arithmetic/1_digit_multiplicati...              0.378045
# 1_registry/data/crass_ai/samples.jsonl                          0.448028
# 1_registry/data/logical_args/samples.jsonl                      0.550962
# 1_registry/data/arithmetic/2_digit_division/sam...              0.678960
# 1_registry/data/emoji_movie/samples.jsonl                       0.826885
# 1_registry/data/arithmetic/3_digit_division/sam...              1.156552
# 1_registry/data/fantasy_reasoning/samples.jsonl                 1.497338
# 1_registry/data/arithmetic/2_digit_multiplicati...              2.130196
# 1_registry/data/arithmetic/2_digit_subtraction/...              2.763055
# 1_registry/data/arithmetic/2_digit_addition/sam...              3.395913
# 1_registry/data/arithmetic/3_digit_multiplicati...              4.047745
# 1_registry/data/arithmetic/3_digit_addition/sam...              4.699701
# 1_registry/data/arithmetic/3_digit_subtraction/...              5.352239
# 1_registry/data/arithmetic/4_digit_multiplicati...              6.020256
# 1_registry/data/arithmetic/4_digit_addition/sam...              6.688556
# 1_registry/data/arithmetic/4_digit_subtraction/...              7.356891
# 1_registry/data/arithmetic/4_digit_division/sam...              8.030079
# 1_registry/data/arithmetic/5_digit_multiplicati...              8.709357
# 1_registry/data/arithmetic/5_digit_addition/sam...              9.388988
# 1_registry/data/arithmetic/5_digit_subtraction/...             10.068813
# 1_registry/data/arithmetic/5_digit_division/sam...             10.751850
# 1_registry/data/copa/samples.jsonl                             11.583889
# 1_registry/data/metaphor_boolean/samples.jsonl                 12.470431
# 1_registry/data/geometric_shapes/samples.jsonl                 13.364739
# 1_registry/data/space_nli/samples.jsonl                        15.826102
# 1_registry/data/goal_step_wikihow/goal_inferenc...             18.701922
# 1_registry/data/abstract_narrative_understandin...             21.654467
# 1_registry/data/alpha_nli/samples.jsonl                        24.882599
# 1_registry/data/ropes/samples.jsonl                            28.730088
# 1_registry/data/abstract_narrative_understandin...             32.605463
# 1_registry/data/goal_step_wikihow/step_inferenc...             36.760520
# 1_registry/data/goal_step_wikihow/step_ordering...             42.761290
# 1_registry/data/anli/samples.jsonl                             51.366424
# 1_registry/data/wanli/samples.jsonl                            60.024085
# 1_registry/data/babi_task_16/samples.jsonl                     69.242891
# 1_registry/data/cosmos_qa/samples.jsonl                        80.298269
# 1_registry/data/abstract_narrative_understandin...            100.446732
# 1_registry/data/formal_fallacies_syllogisms_neg...            134.634324
#
#                                                     total_cost  \
# 1_registry/data/arithmetic/1_digit_division/sam...    0.012408
# 1_registry/data/cause_and_effect/one_sentence_n...    0.025716
# 1_registry/data/odd_one_out/samples.jsonl             0.044602
# 1_registry/data/cause_and_effect/two_sentences/...    0.053215
# 1_registry/data/cause_and_effect/one_sentence/s...    0.059110
# 1_registry/data/arithmetic/1_digit_subtraction/...    0.060998
# 1_registry/data/arithmetic/1_digit_addition/sam...    0.060998
# 1_registry/data/arithmetic/1_digit_multiplicati...    0.060998
# 1_registry/data/crass_ai/samples.jsonl                0.069982
# 1_registry/data/logical_args/samples.jsonl            0.102935
# 1_registry/data/arithmetic/2_digit_division/sam...    0.127998
# 1_registry/data/emoji_movie/samples.jsonl             0.147925
# 1_registry/data/arithmetic/3_digit_division/sam...    0.329667
# 1_registry/data/fantasy_reasoning/samples.jsonl       0.340786
# 1_registry/data/arithmetic/2_digit_multiplicati...    0.632858
# 1_registry/data/arithmetic/2_digit_subtraction/...    0.632858
# 1_registry/data/arithmetic/2_digit_addition/sam...    0.632858
# 1_registry/data/arithmetic/3_digit_multiplicati...    0.651832
# 1_registry/data/arithmetic/3_digit_addition/sam...    0.651956
# 1_registry/data/arithmetic/3_digit_subtraction/...    0.652538
# 1_registry/data/arithmetic/4_digit_multiplicati...    0.668017
# 1_registry/data/arithmetic/4_digit_addition/sam...    0.668300
# 1_registry/data/arithmetic/4_digit_subtraction/...    0.668335
# 1_registry/data/arithmetic/4_digit_division/sam...    0.673189
# 1_registry/data/arithmetic/5_digit_multiplicati...    0.679278
# 1_registry/data/arithmetic/5_digit_addition/sam...    0.679631
# 1_registry/data/arithmetic/5_digit_subtraction/...    0.679825
# 1_registry/data/arithmetic/5_digit_division/sam...    0.683037
# 1_registry/data/copa/samples.jsonl                    0.832039
# 1_registry/data/metaphor_boolean/samples.jsonl        0.886542
# 1_registry/data/geometric_shapes/samples.jsonl        0.894308
# 1_registry/data/space_nli/samples.jsonl               2.461363
# 1_registry/data/goal_step_wikihow/goal_inferenc...    2.875820
# 1_registry/data/abstract_narrative_understandin...    2.952545
# 1_registry/data/alpha_nli/samples.jsonl               3.228132
# 1_registry/data/ropes/samples.jsonl                   3.847488
# 1_registry/data/abstract_narrative_understandin...    3.875375
# 1_registry/data/goal_step_wikihow/step_inferenc...    4.155057
# 1_registry/data/goal_step_wikihow/step_ordering...    6.000771
# 1_registry/data/anli/samples.jsonl                    8.605134
# 1_registry/data/wanli/samples.jsonl                   8.657660
# 1_registry/data/babi_task_16/samples.jsonl            9.218807
# 1_registry/data/cosmos_qa/samples.jsonl              11.055378
# 1_registry/data/abstract_narrative_understandin...   20.148463
# 1_registry/data/formal_fallacies_syllogisms_neg...   34.187591
#
#                                                     cumsum_n_samples  \
# 1_registry/data/arithmetic/1_digit_division/sam...              19.0
# 1_registry/data/cause_and_effect/one_sentence_n...              66.0
# 1_registry/data/odd_one_out/samples.jsonl                      148.0
# 1_registry/data/cause_and_effect/two_sentences/...             195.0
# 1_registry/data/cause_and_effect/one_sentence/s...             242.0
# 1_registry/data/arithmetic/1_digit_subtraction/...             338.0
# 1_registry/data/arithmetic/1_digit_addition/sam...             434.0
# 1_registry/data/arithmetic/1_digit_multiplicati...             530.0
# 1_registry/data/crass_ai/samples.jsonl                         570.0
# 1_registry/data/logical_args/samples.jsonl                     598.0
# 1_registry/data/arithmetic/2_digit_division/sam...             794.0
# 1_registry/data/emoji_movie/samples.jsonl                      890.0
# 1_registry/data/arithmetic/3_digit_division/sam...            1386.0
# 1_registry/data/fantasy_reasoning/samples.jsonl               1583.0
# 1_registry/data/arithmetic/2_digit_multiplicati...            2579.0
# 1_registry/data/arithmetic/2_digit_subtraction/...            3575.0
# 1_registry/data/arithmetic/2_digit_addition/sam...            4571.0
# 1_registry/data/arithmetic/3_digit_multiplicati...            5567.0
# 1_registry/data/arithmetic/3_digit_addition/sam...            6563.0
# 1_registry/data/arithmetic/3_digit_subtraction/...            7559.0
# 1_registry/data/arithmetic/4_digit_multiplicati...            8555.0
# 1_registry/data/arithmetic/4_digit_addition/sam...            9551.0
# 1_registry/data/arithmetic/4_digit_subtraction/...           10547.0
# 1_registry/data/arithmetic/4_digit_division/sam...           11543.0
# 1_registry/data/arithmetic/5_digit_multiplicati...           12539.0
# 1_registry/data/arithmetic/5_digit_addition/sam...           13535.0
# 1_registry/data/arithmetic/5_digit_subtraction/...           14531.0
# 1_registry/data/arithmetic/5_digit_division/sam...           15527.0
# 1_registry/data/copa/samples.jsonl                           16023.0
# 1_registry/data/metaphor_boolean/samples.jsonl               16699.0
# 1_registry/data/geometric_shapes/samples.jsonl               17055.0
# 1_registry/data/space_nli/samples.jsonl                      18655.0
# 1_registry/data/goal_step_wikihow/goal_inferenc...           20354.0
# 1_registry/data/abstract_narrative_understandin...           21350.0
# 1_registry/data/alpha_nli/samples.jsonl                      22878.0
# 1_registry/data/ropes/samples.jsonl                          24562.0
# 1_registry/data/abstract_narrative_understandin...           25558.0
# 1_registry/data/goal_step_wikihow/step_inferenc...           27804.0
# 1_registry/data/goal_step_wikihow/step_ordering...           30900.0
# 1_registry/data/anli/samples.jsonl                           34096.0
# 1_registry/data/wanli/samples.jsonl                          39092.0
# 1_registry/data/babi_task_16/samples.jsonl                   44088.0
# 1_registry/data/cosmos_qa/samples.jsonl                      47069.0
# 1_registry/data/abstract_narrative_understandin...           48065.0
# 1_registry/data/formal_fallacies_syllogisms_neg...           62261.0
#
#                                                     n_samples
# 1_registry/data/arithmetic/1_digit_division/sam...       19.0
# 1_registry/data/cause_and_effect/one_sentence_n...       47.0
# 1_registry/data/odd_one_out/samples.jsonl                82.0
# 1_registry/data/cause_and_effect/two_sentences/...       47.0
# 1_registry/data/cause_and_effect/one_sentence/s...       47.0
# 1_registry/data/arithmetic/1_digit_subtraction/...       96.0
# 1_registry/data/arithmetic/1_digit_addition/sam...       96.0
# 1_registry/data/arithmetic/1_digit_multiplicati...       96.0
# 1_registry/data/crass_ai/samples.jsonl                   40.0
# 1_registry/data/logical_args/samples.jsonl               28.0
# 1_registry/data/arithmetic/2_digit_division/sam...      196.0
# 1_registry/data/emoji_movie/samples.jsonl                96.0
# 1_registry/data/arithmetic/3_digit_division/sam...      496.0
# 1_registry/data/fantasy_reasoning/samples.jsonl         197.0
# 1_registry/data/arithmetic/2_digit_multiplicati...      996.0
# 1_registry/data/arithmetic/2_digit_subtraction/...      996.0
# 1_registry/data/arithmetic/2_digit_addition/sam...      996.0
# 1_registry/data/arithmetic/3_digit_multiplicati...      996.0
# 1_registry/data/arithmetic/3_digit_addition/sam...      996.0
# 1_registry/data/arithmetic/3_digit_subtraction/...      996.0
# 1_registry/data/arithmetic/4_digit_multiplicati...      996.0
# 1_registry/data/arithmetic/4_digit_addition/sam...      996.0
# 1_registry/data/arithmetic/4_digit_subtraction/...      996.0
# 1_registry/data/arithmetic/4_digit_division/sam...      996.0
# 1_registry/data/arithmetic/5_digit_multiplicati...      996.0
# 1_registry/data/arithmetic/5_digit_addition/sam...      996.0
# 1_registry/data/arithmetic/5_digit_subtraction/...      996.0
# 1_registry/data/arithmetic/5_digit_division/sam...      996.0
# 1_registry/data/copa/samples.jsonl                      496.0
# 1_registry/data/metaphor_boolean/samples.jsonl          676.0
# 1_registry/data/geometric_shapes/samples.jsonl          356.0
# 1_registry/data/space_nli/samples.jsonl                1600.0
# 1_registry/data/goal_step_wikihow/goal_inferenc...     1699.0
# 1_registry/data/abstract_narrative_understandin...      996.0
# 1_registry/data/alpha_nli/samples.jsonl                1528.0
# 1_registry/data/ropes/samples.jsonl                    1684.0
# 1_registry/data/abstract_narrative_understandin...      996.0
# 1_registry/data/goal_step_wikihow/step_inferenc...     2246.0
# 1_registry/data/goal_step_wikihow/step_ordering...     3096.0
# 1_registry/data/anli/samples.jsonl                     3196.0
# 1_registry/data/wanli/samples.jsonl                    4996.0
# 1_registry/data/babi_task_16/samples.jsonl             4996.0
# 1_registry/data/cosmos_qa/samples.jsonl                2981.0
# 1_registry/data/abstract_narrative_understandin...      996.0
# 1_registry/data/formal_fallacies_syllogisms_neg...    14196.0

# %% [markdown]
# # Compute the cost by keeping only a subset of samples for some dataset
#
# For some datasets, if I run on all samples, the cost is too high -> reduce the cost by keeping only 1000 samples for some of them

# %%
evals_cheap = ['odd_one_out',
 'crass_ai',
 'logical_args',
 'emoji_movie',
 'fantasy_reasoning',
 'metaphor_boolean',
 'geometric_shapes',
 'space_nli',
 'copa',
 'anli',
 'cosmos_qa',
 'ropes',
 'arithmetic']

# %%
len(evals_cheap)
# Out:
# 13

# %%
# extract all other evals that are not in evals_cheap
evals_expensive = list(set(DATASETS_DICT.keys()) - set(evals_cheap))

# %%
evals_expensive
# Out:
# ['babi_task_16',
#  'wanli',
#  'goal_step_wikihow',
#  'formal_fallacies_syllogisms_negation',
#  'abstract_narrative_understanding',
#  'alpha_nli',
#  'cause_and_effect']

# %% [markdown]
# ## Cost computation

# %%
# copy n_tokens_df and redefine the index with .split("data/")[1].split("/samples")[0].replace("/", "_") 
n_tokens_df_new_index = n_tokens_df.copy()
n_tokens_df_new_index.index = [i.split("data/")[1].split("/samples")[0].replace("/", "_") for i in n_tokens_df.index]

# %%
n_tokens_df_new_index
# Out:
#                                                  n_tokens  \
# arithmetic_1_digit_division                           703
# cause_and_effect_one_sentence_no_prompt              1457
# odd_one_out                                          2527
# cause_and_effect_two_sentences                       3015
# cause_and_effect_one_sentence                        3349
# arithmetic_1_digit_subtraction                       3456
# arithmetic_1_digit_addition                          3456
# arithmetic_1_digit_multiplication                    3456
# crass_ai                                             3965
# logical_args                                         5832
# arithmetic_2_digit_division                          7252
# emoji_movie                                          8381
# arithmetic_3_digit_division                         18678
# fantasy_reasoning                                   19308
# arithmetic_2_digit_multiplication                   35856
# arithmetic_2_digit_subtraction                      35856
# arithmetic_2_digit_addition                         35856
# arithmetic_3_digit_multiplication                   36931
# arithmetic_3_digit_addition                         36938
# arithmetic_3_digit_subtraction                      36971
# arithmetic_4_digit_multiplication                   37848
# arithmetic_4_digit_addition                         37864
# arithmetic_4_digit_subtraction                      37866
# arithmetic_4_digit_division                         38141
# arithmetic_5_digit_multiplication                   38486
# arithmetic_5_digit_addition                         38506
# arithmetic_5_digit_subtraction                      38517
# arithmetic_5_digit_division                         38699
# copa                                                47141
# metaphor_boolean                                    50229
# geometric_shapes                                    50669
# space_nli                                          139454
# goal_step_wikihow_goal_inference                   162936
# abstract_narrative_understanding_4_distractors     167283
# alpha_nli                                          182897
# ropes                                              217988
# abstract_narrative_understanding_9_distractors     219568
# goal_step_wikihow_step_inference                   235414
# goal_step_wikihow_step_ordering                    339987
# anli                                               487543
# wanli                                              490519
# babi_task_16                                       522312
# cosmos_qa                                          626367
# abstract_narrative_understanding_99_distractors   1141556
# formal_fallacies_syllogisms_negation              1936974
#
#                                                  cost_gpt-4o-2024-08-06  \
# arithmetic_1_digit_division                                    0.001758
# cause_and_effect_one_sentence_no_prompt                        0.003643
# odd_one_out                                                    0.006318
# cause_and_effect_two_sentences                                 0.007538
# cause_and_effect_one_sentence                                  0.008373
# arithmetic_1_digit_subtraction                                 0.008640
# arithmetic_1_digit_addition                                    0.008640
# arithmetic_1_digit_multiplication                              0.008640
# crass_ai                                                       0.009913
# logical_args                                                   0.014580
# arithmetic_2_digit_division                                    0.018130
# emoji_movie                                                    0.020953
# arithmetic_3_digit_division                                    0.046695
# fantasy_reasoning                                              0.048270
# arithmetic_2_digit_multiplication                              0.089640
# arithmetic_2_digit_subtraction                                 0.089640
# arithmetic_2_digit_addition                                    0.089640
# arithmetic_3_digit_multiplication                              0.092328
# arithmetic_3_digit_addition                                    0.092345
# arithmetic_3_digit_subtraction                                 0.092428
# arithmetic_4_digit_multiplication                              0.094620
# arithmetic_4_digit_addition                                    0.094660
# arithmetic_4_digit_subtraction                                 0.094665
# arithmetic_4_digit_division                                    0.095353
# arithmetic_5_digit_multiplication                              0.096215
# arithmetic_5_digit_addition                                    0.096265
# arithmetic_5_digit_subtraction                                 0.096293
# arithmetic_5_digit_division                                    0.096748
# copa                                                           0.117853
# metaphor_boolean                                               0.125573
# geometric_shapes                                               0.126673
# space_nli                                                      0.348635
# goal_step_wikihow_goal_inference                               0.407340
# abstract_narrative_understanding_4_distractors                 0.418208
# alpha_nli                                                      0.457243
# ropes                                                          0.544970
# abstract_narrative_understanding_9_distractors                 0.548920
# goal_step_wikihow_step_inference                               0.588535
# goal_step_wikihow_step_ordering                                0.849968
# anli                                                           1.218858
# wanli                                                          1.226298
# babi_task_16                                                   1.305780
# cosmos_qa                                                      1.565918
# abstract_narrative_understanding_99_distractors                2.853890
# formal_fallacies_syllogisms_negation                           4.842435
#
#                                                  cost_gpt-4o-2024-05-13  \
# arithmetic_1_digit_division                                    0.003515
# cause_and_effect_one_sentence_no_prompt                        0.007285
# odd_one_out                                                    0.012635
# cause_and_effect_two_sentences                                 0.015075
# cause_and_effect_one_sentence                                  0.016745
# arithmetic_1_digit_subtraction                                 0.017280
# arithmetic_1_digit_addition                                    0.017280
# arithmetic_1_digit_multiplication                              0.017280
# crass_ai                                                       0.019825
# logical_args                                                   0.029160
# arithmetic_2_digit_division                                    0.036260
# emoji_movie                                                    0.041905
# arithmetic_3_digit_division                                    0.093390
# fantasy_reasoning                                              0.096540
# arithmetic_2_digit_multiplication                              0.179280
# arithmetic_2_digit_subtraction                                 0.179280
# arithmetic_2_digit_addition                                    0.179280
# arithmetic_3_digit_multiplication                              0.184655
# arithmetic_3_digit_addition                                    0.184690
# arithmetic_3_digit_subtraction                                 0.184855
# arithmetic_4_digit_multiplication                              0.189240
# arithmetic_4_digit_addition                                    0.189320
# arithmetic_4_digit_subtraction                                 0.189330
# arithmetic_4_digit_division                                    0.190705
# arithmetic_5_digit_multiplication                              0.192430
# arithmetic_5_digit_addition                                    0.192530
# arithmetic_5_digit_subtraction                                 0.192585
# arithmetic_5_digit_division                                    0.193495
# copa                                                           0.235705
# metaphor_boolean                                               0.251145
# geometric_shapes                                               0.253345
# space_nli                                                      0.697270
# goal_step_wikihow_goal_inference                               0.814680
# abstract_narrative_understanding_4_distractors                 0.836415
# alpha_nli                                                      0.914485
# ropes                                                          1.089940
# abstract_narrative_understanding_9_distractors                 1.097840
# goal_step_wikihow_step_inference                               1.177070
# goal_step_wikihow_step_ordering                                1.699935
# anli                                                           2.437715
# wanli                                                          2.452595
# babi_task_16                                                   2.611560
# cosmos_qa                                                      3.131835
# abstract_narrative_understanding_99_distractors                5.707780
# formal_fallacies_syllogisms_negation                           9.684870
#
#                                                  cost_gpt-4o-mini-2024-07-18  \
# arithmetic_1_digit_division                                         0.000105
# cause_and_effect_one_sentence_no_prompt                             0.000219
# odd_one_out                                                         0.000379
# cause_and_effect_two_sentences                                      0.000452
# cause_and_effect_one_sentence                                       0.000502
# arithmetic_1_digit_subtraction                                      0.000518
# arithmetic_1_digit_addition                                         0.000518
# arithmetic_1_digit_multiplication                                   0.000518
# crass_ai                                                            0.000595
# logical_args                                                        0.000875
# arithmetic_2_digit_division                                         0.001088
# emoji_movie                                                         0.001257
# arithmetic_3_digit_division                                         0.002802
# fantasy_reasoning                                                   0.002896
# arithmetic_2_digit_multiplication                                   0.005378
# arithmetic_2_digit_subtraction                                      0.005378
# arithmetic_2_digit_addition                                         0.005378
# arithmetic_3_digit_multiplication                                   0.005540
# arithmetic_3_digit_addition                                         0.005541
# arithmetic_3_digit_subtraction                                      0.005546
# arithmetic_4_digit_multiplication                                   0.005677
# arithmetic_4_digit_addition                                         0.005680
# arithmetic_4_digit_subtraction                                      0.005680
# arithmetic_4_digit_division                                         0.005721
# arithmetic_5_digit_multiplication                                   0.005773
# arithmetic_5_digit_addition                                         0.005776
# arithmetic_5_digit_subtraction                                      0.005778
# arithmetic_5_digit_division                                         0.005805
# copa                                                                0.007071
# metaphor_boolean                                                    0.007534
# geometric_shapes                                                    0.007600
# space_nli                                                           0.020918
# goal_step_wikihow_goal_inference                                    0.024440
# abstract_narrative_understanding_4_distractors                      0.025092
# alpha_nli                                                           0.027435
# ropes                                                               0.032698
# abstract_narrative_understanding_9_distractors                      0.032935
# goal_step_wikihow_step_inference                                    0.035312
# goal_step_wikihow_step_ordering                                     0.050998
# anli                                                                0.073131
# wanli                                                               0.073578
# babi_task_16                                                        0.078347
# cosmos_qa                                                           0.093955
# abstract_narrative_understanding_99_distractors                     0.171233
# formal_fallacies_syllogisms_negation                                0.290546
#
#                                                  cost_gpt-4-turbo-2024-04-09  \
# arithmetic_1_digit_division                                          0.00703
# cause_and_effect_one_sentence_no_prompt                              0.01457
# odd_one_out                                                          0.02527
# cause_and_effect_two_sentences                                       0.03015
# cause_and_effect_one_sentence                                        0.03349
# arithmetic_1_digit_subtraction                                       0.03456
# arithmetic_1_digit_addition                                          0.03456
# arithmetic_1_digit_multiplication                                    0.03456
# crass_ai                                                             0.03965
# logical_args                                                         0.05832
# arithmetic_2_digit_division                                          0.07252
# emoji_movie                                                          0.08381
# arithmetic_3_digit_division                                          0.18678
# fantasy_reasoning                                                    0.19308
# arithmetic_2_digit_multiplication                                    0.35856
# arithmetic_2_digit_subtraction                                       0.35856
# arithmetic_2_digit_addition                                          0.35856
# arithmetic_3_digit_multiplication                                    0.36931
# arithmetic_3_digit_addition                                          0.36938
# arithmetic_3_digit_subtraction                                       0.36971
# arithmetic_4_digit_multiplication                                    0.37848
# arithmetic_4_digit_addition                                          0.37864
# arithmetic_4_digit_subtraction                                       0.37866
# arithmetic_4_digit_division                                          0.38141
# arithmetic_5_digit_multiplication                                    0.38486
# arithmetic_5_digit_addition                                          0.38506
# arithmetic_5_digit_subtraction                                       0.38517
# arithmetic_5_digit_division                                          0.38699
# copa                                                                 0.47141
# metaphor_boolean                                                     0.50229
# geometric_shapes                                                     0.50669
# space_nli                                                            1.39454
# goal_step_wikihow_goal_inference                                     1.62936
# abstract_narrative_understanding_4_distractors                       1.67283
# alpha_nli                                                            1.82897
# ropes                                                                2.17988
# abstract_narrative_understanding_9_distractors                       2.19568
# goal_step_wikihow_step_inference                                     2.35414
# goal_step_wikihow_step_ordering                                      3.39987
# anli                                                                 4.87543
# wanli                                                                4.90519
# babi_task_16                                                         5.22312
# cosmos_qa                                                            6.26367
# abstract_narrative_understanding_99_distractors                     11.41556
# formal_fallacies_syllogisms_negation                                19.36974
#
#                                                  total_cost  n_samples  \
# arithmetic_1_digit_division                        0.012408       19.0
# cause_and_effect_one_sentence_no_prompt            0.025716       47.0
# odd_one_out                                        0.044602       82.0
# cause_and_effect_two_sentences                     0.053215       47.0
# cause_and_effect_one_sentence                      0.059110       47.0
# arithmetic_1_digit_subtraction                     0.060998       96.0
# arithmetic_1_digit_addition                        0.060998       96.0
# arithmetic_1_digit_multiplication                  0.060998       96.0
# crass_ai                                           0.069982       40.0
# logical_args                                       0.102935       28.0
# arithmetic_2_digit_division                        0.127998      196.0
# emoji_movie                                        0.147925       96.0
# arithmetic_3_digit_division                        0.329667      496.0
# fantasy_reasoning                                  0.340786      197.0
# arithmetic_2_digit_multiplication                  0.632858      996.0
# arithmetic_2_digit_subtraction                     0.632858      996.0
# arithmetic_2_digit_addition                        0.632858      996.0
# arithmetic_3_digit_multiplication                  0.651832      996.0
# arithmetic_3_digit_addition                        0.651956      996.0
# arithmetic_3_digit_subtraction                     0.652538      996.0
# arithmetic_4_digit_multiplication                  0.668017      996.0
# arithmetic_4_digit_addition                        0.668300      996.0
# arithmetic_4_digit_subtraction                     0.668335      996.0
# arithmetic_4_digit_division                        0.673189      996.0
# arithmetic_5_digit_multiplication                  0.679278      996.0
# arithmetic_5_digit_addition                        0.679631      996.0
# arithmetic_5_digit_subtraction                     0.679825      996.0
# arithmetic_5_digit_division                        0.683037      996.0
# copa                                               0.832039      496.0
# metaphor_boolean                                   0.886542      676.0
# geometric_shapes                                   0.894308      356.0
# space_nli                                          2.461363     1600.0
# goal_step_wikihow_goal_inference                   2.875820     1699.0
# abstract_narrative_understanding_4_distractors     2.952545      996.0
# alpha_nli                                          3.228132     1528.0
# ropes                                              3.847488     1684.0
# abstract_narrative_understanding_9_distractors     3.875375      996.0
# goal_step_wikihow_step_inference                   4.155057     2246.0
# goal_step_wikihow_step_ordering                    6.000771     3096.0
# anli                                               8.605134     3196.0
# wanli                                              8.657660     4996.0
# babi_task_16                                       9.218807     4996.0
# cosmos_qa                                         11.055378     2981.0
# abstract_narrative_understanding_99_distractors   20.148463      996.0
# formal_fallacies_syllogisms_negation              34.187591    14196.0
#
#                                                  cumsum_cost_instruct  \
# arithmetic_1_digit_division                                  0.012408
# cause_and_effect_one_sentence_no_prompt                      0.038124
# odd_one_out                                                  0.082726
# cause_and_effect_two_sentences                               0.135940
# cause_and_effect_one_sentence                                0.195050
# arithmetic_1_digit_subtraction                               0.256049
# arithmetic_1_digit_addition                                  0.317047
# arithmetic_1_digit_multiplication                            0.378045
# crass_ai                                                     0.448028
# logical_args                                                 0.550962
# arithmetic_2_digit_division                                  0.678960
# emoji_movie                                                  0.826885
# arithmetic_3_digit_division                                  1.156552
# fantasy_reasoning                                            1.497338
# arithmetic_2_digit_multiplication                            2.130196
# arithmetic_2_digit_subtraction                               2.763055
# arithmetic_2_digit_addition                                  3.395913
# arithmetic_3_digit_multiplication                            4.047745
# arithmetic_3_digit_addition                                  4.699701
# arithmetic_3_digit_subtraction                               5.352239
# arithmetic_4_digit_multiplication                            6.020256
# arithmetic_4_digit_addition                                  6.688556
# arithmetic_4_digit_subtraction                               7.356891
# arithmetic_4_digit_division                                  8.030079
# arithmetic_5_digit_multiplication                            8.709357
# arithmetic_5_digit_addition                                  9.388988
# arithmetic_5_digit_subtraction                              10.068813
# arithmetic_5_digit_division                                 10.751850
# copa                                                        11.583889
# metaphor_boolean                                            12.470431
# geometric_shapes                                            13.364739
# space_nli                                                   15.826102
# goal_step_wikihow_goal_inference                            18.701922
# abstract_narrative_understanding_4_distractors              21.654467
# alpha_nli                                                   24.882599
# ropes                                                       28.730088
# abstract_narrative_understanding_9_distractors              32.605463
# goal_step_wikihow_step_inference                            36.760520
# goal_step_wikihow_step_ordering                             42.761290
# anli                                                        51.366424
# wanli                                                       60.024085
# babi_task_16                                                69.242891
# cosmos_qa                                                   80.298269
# abstract_narrative_understanding_99_distractors            100.446732
# formal_fallacies_syllogisms_negation                       134.634324
#
#                                                  cumsum_n_samples
# arithmetic_1_digit_division                                  19.0
# cause_and_effect_one_sentence_no_prompt                      66.0
# odd_one_out                                                 148.0
# cause_and_effect_two_sentences                              195.0
# cause_and_effect_one_sentence                               242.0
# arithmetic_1_digit_subtraction                              338.0
# arithmetic_1_digit_addition                                 434.0
# arithmetic_1_digit_multiplication                           530.0
# crass_ai                                                    570.0
# logical_args                                                598.0
# arithmetic_2_digit_division                                 794.0
# emoji_movie                                                 890.0
# arithmetic_3_digit_division                                1386.0
# fantasy_reasoning                                          1583.0
# arithmetic_2_digit_multiplication                          2579.0
# arithmetic_2_digit_subtraction                             3575.0
# arithmetic_2_digit_addition                                4571.0
# arithmetic_3_digit_multiplication                          5567.0
# arithmetic_3_digit_addition                                6563.0
# arithmetic_3_digit_subtraction                             7559.0
# arithmetic_4_digit_multiplication                          8555.0
# arithmetic_4_digit_addition                                9551.0
# arithmetic_4_digit_subtraction                            10547.0
# arithmetic_4_digit_division                               11543.0
# arithmetic_5_digit_multiplication                         12539.0
# arithmetic_5_digit_addition                               13535.0
# arithmetic_5_digit_subtraction                            14531.0
# arithmetic_5_digit_division                               15527.0
# copa                                                      16023.0
# metaphor_boolean                                          16699.0
# geometric_shapes                                          17055.0
# space_nli                                                 18655.0
# goal_step_wikihow_goal_inference                          20354.0
# abstract_narrative_understanding_4_distractors            21350.0
# alpha_nli                                                 22878.0
# ropes                                                     24562.0
# abstract_narrative_understanding_9_distractors            25558.0
# goal_step_wikihow_step_inference                          27804.0
# goal_step_wikihow_step_ordering                           30900.0
# anli                                                      34096.0
# wanli                                                     39092.0
# babi_task_16                                              44088.0
# cosmos_qa                                                 47069.0
# abstract_narrative_understanding_99_distractors           48065.0
# formal_fallacies_syllogisms_negation                      62261.0

# %%
# compute the total cost with 1000 samples
n_tokens_df_new_index["total_cost_1000"] = n_tokens_df_new_index.apply(lambda x: x["total_cost"]/x["n_samples"] * 1000, axis=1)

# %%
# total cost of the cheap evals on instruct and base models
# loop over rows and check if index startswith a cheapeval
# total cost of the cheap evals on instruct and base models
total_cost_cheap = 0
for index, row in n_tokens_df_new_index.iterrows():
    if any(index.startswith(eval) for eval in evals_cheap):
        total_cost_cheap += row["total_cost"]

print(f"Total cost of cheap evals on instruct and base models: {total_cost_cheap:.2f}")
# Out:
# Total cost of cheap evals on instruct and base models: 39.20

# %%
# total cost of the expensive evals on instruct and base models
# loop over rows and check if index startswith a expensiveeval
# total cost of the expensive evals on instruct and base models
total_cost_expensive = 0
for index, row in n_tokens_df_new_index.iterrows():
    if any(index.startswith(eval) for eval in evals_expensive):
        total_cost_expensive += row["total_cost_1000"]

print(f"Total cost of expensive evals on instruct and base models: {total_cost_expensive:.2f}")
# Out:
# Total cost of expensive evals on instruct and base models: 43.60

# %%
grand_total = total_cost_cheap  + total_cost_expensive
print(f"Grand total: {grand_total:.2f}")
# Out:
# Grand total: 82.80
